# %% [markdown]
# <a href="https://colab.research.google.com/github/sharma1saransh/python/blob/main/pandass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
np.arange(0,20).reshape(4,5)
df=pd.DataFrame(data=np.arange(0,20).reshape(4,5),index=["r1","r2","r3","r4"], columns=["c1","c2","c3","c4","c5"])
df.head()
df.tail()
df.describe()
# Out:
#               c1         c2         c3         c4         c5
# count   4.000000   4.000000   4.000000   4.000000   4.000000
# mean    7.500000   8.500000   9.500000  10.500000  11.500000
# std     6.454972   6.454972   6.454972   6.454972   6.454972
# min     0.000000   1.000000   2.000000   3.000000   4.000000
# 25%     3.750000   4.750000   5.750000   6.750000   7.750000
# 50%     7.500000   8.500000   9.500000  10.500000  11.500000
# 75%    11.250000  12.250000  13.250000  14.250000  15.250000
# max    15.000000  16.000000  17.000000  18.000000  19.000000
